# %%
# 🧠 Fraud Guardian - Project Overview

## 1. Objective
Detect fraudulent credit card transactions using machine learning, balancing recall and precision to minimize financial losses and false alarms.

## 2. Dataset
- Source: Kaggle (Credit Card Fraud Detection)
- Size: 284,807 transactions
- Class 1 (fraud): ~0.17%
- Features: 30 (V1–V28 from PCA + Amount + Time)

## 3. Methodology
1. Exploratory Data Analysis (EDA)
2. Preprocessing (scaling, imbalance handling)
3. Modeling (Logistic Regression, RandomForest, XGBoost)
4. Threshold Optimization
5. Explainability (SHAP)
6. Reporting & Visualization

## 4. Evaluation Metrics
- Recall → primary (catch as many frauds as possible)
- Precision → secondary (minimize false alerts)
- AUC-ROC and F1-score for balance assessment

## 5. Expected Outcome
A deployable fraud detection model that identifies >90% of fraudulent transactions while keeping false positives at a manageable level.
